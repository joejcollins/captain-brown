# %% [markdown]
# # Dummy Plot
#
# Yes, it's dumb.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 25]

# Create a line plot
plt.plot(x, y, marker='o')
plt.title('Sample Line Plotting')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.savefig("../reports/2025_03_26_dummy/figures/dummy_plot.png", dpi=300) 
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
